# %%
import random
random.seed(0)

import numpy as np
np.random.seed(0)

import tensorflow as tf
tf.random.set_seed(0)

import pandas as pd

# %%
from tensorflow.keras import datasets , models , layers
import matplotlib.pyplot as plt

# %%
import zipfile
import os

# %%
zip_file_path = 'archive (2).zip'

# %%
# Define the directory to unzip into
unzip_dir = 'archive(2)'  # You can specify your own directory name

# Create the directory if it doesn't exist
os.makedirs(unzip_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(unzip_dir)

print(f'Unzipped files to: {unzip_dir}')
# Out:
# Unzipped files to: archive(2)

# %%
import os
import shutil
import random

def split_dataset(source_dir, train_dir, test_dir, val_dir, train_ratio=0.8, val_ratio=0.1):
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    for category in os.listdir(source_dir):
        category_path = os.path.join(source_dir, category)
        if os.path.isdir(category_path):
            images = os.listdir(category_path)
            random.shuffle(images)

            # Create class directories in train, test, and val folders
            train_class_dir = os.path.join(train_dir, category)
            test_class_dir = os.path.join(test_dir, category)
            val_class_dir = os.path.join(val_dir, category)
            os.makedirs(train_class_dir, exist_ok=True)
            os.makedirs(test_class_dir, exist_ok=True)
            os.makedirs(val_class_dir, exist_ok=True)

            train_size = int(len(images) * train_ratio)
            val_size = int(len(images) * val_ratio)

            # Copy images to the respective directories
            for img in images[:train_size]:
                shutil.copy(os.path.join(category_path, img), os.path.join(train_class_dir, img))
            for img in images[train_size:train_size + val_size]:
                shutil.copy(os.path.join(category_path, img), os.path.join(val_class_dir, img))
            for img in images[train_size + val_size:]:
                shutil.copy(os.path.join(category_path, img), os.path.join(test_class_dir, img))

# Define your directory paths
source_directory = 'archive(2)/archive'
train_directory = 'train'
test_directory = 'test'
val_directory = 'val'

split_dataset(source_directory, train_directory, test_directory, val_directory)

# %%
import os

train_dir = 'train'

# List all files in the train directory
print(os.listdir(train_dir))
# Out:
# ['FreshApple', 'FreshBanana', 'FreshBellpepper', 'FreshCarrot', 'FreshCucumber', 'FreshMango', 'FreshOrange', 'FreshPotato', 'FreshStrawberry', 'FreshTomato', 'RottenApple', 'RottenBanana', 'RottenBellpepper', 'RottenCarrot', 'RottenCucumber', 'RottenMango', 'RottenOrange', 'RottenPotato', 'RottenStrawberry', 'RottenTomato']

# %%
img_width = 180
img_height = 180

# %%
import os
import cv2
import imghdr

image_exts = ['jpeg', 'png', 'jpg', 'gif', 'bmp'] 

for image_class in os.listdir(train_directory):
    class_dir = os.path.join(train_directory, image_class)
    if os.path.isdir(class_dir):  
        for image in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image)
            try:
                img = cv2.imread(image_path)
                tip = imghdr.what(image_path)
                if tip not in image_exts:
                    print('Image not in correct form: {}'.format(image_path))
                    os.remove(image_path)
            except Exception as e:
                print('Issue with image {}: {}'.format(image_path, e))
# Out:
# Image not in correct form: train\FreshBanana\freshBanana (1).jpg
# Image not in correct form: train\FreshBanana\freshBanana (418).jpg
# Image not in correct form: train\FreshBanana\freshBanana (422).jpg
# Image not in correct form: train\FreshCarrot\freshCarrot (1).webp
# Image not in correct form: train\FreshCarrot\freshCarrot (415).jpg
# Image not in correct form: train\FreshCarrot\freshCarrot (545).jpg
# Issue with image train\FreshCucumber\.ipynb_checkpoints: [Errno 13] Permission denied: 'train\\FreshCucumber\\.ipynb_checkpoints'
# Image not in correct form: train\FreshCucumber\freshCucumber (1).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (100).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (102).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (103).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (105).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (106).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (108).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (109).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (111).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (112).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (113).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (114).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (115).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (117).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (119).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (120).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (122).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (123).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (124).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (133).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (134).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (135).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (136).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (137).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (138).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (139).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (140).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (142).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (143).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (145).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (146).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (147).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (148).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (151).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (152).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (153).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (155).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (156).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (157).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (158).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (159).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (160).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (161).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (162).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (163).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (164).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (165).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (166).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (167).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (2).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (3).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (31).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (32).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (33).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (34).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (35).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (36).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (38).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (39).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (4).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (40).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (41).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (42).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (43).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (44).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (46).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (47).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (48).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (5).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (50).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (51).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (52).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (529).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (530).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (531).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (532).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (534).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (535).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (536).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (537).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (538).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (54).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (540).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (542).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (547).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (549).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (55).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (551).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (552).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (553).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (554).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (555).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (557).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (558).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (561).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (562).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (563).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (564).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (565).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (566).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (568).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (569).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (57).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (571).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (572).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (574).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (577).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (578).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (579).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (58).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (580).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (582).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (583).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (584).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (585).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (587).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (588).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (589).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (59).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (590).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (591).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (592).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (593).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (594).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (6).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (60).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (62).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (63).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (64).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (66).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (67).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (68).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (69).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (7).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (70).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (71).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (72).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (74).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (75).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (76).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (77).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (78).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (79).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (80).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (82).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (83).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (84).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (85).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (86).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (87).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (88).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (89).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (91).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (92).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (93).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (94).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (95).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (96).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (97).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (98).jpg
# Image not in correct form: train\FreshCucumber\freshCucumber (99).jpg
# Image not in correct form: train\FreshPotato\freshPotato (1).webp
# Image not in correct form: train\RottenApple\rottenApple (2).webp
# Image not in correct form: train\RottenApple\rottenApple (3).webp
# Image not in correct form: train\RottenApple\rottenApple (4).webp
# Image not in correct form: train\RottenApple\rottenApple (459).jpg
# Image not in correct form: train\RottenApple\rottenApple (462).jpg
# Image not in correct form: train\RottenApple\rottenApple (5).webp
# Image not in correct form: train\RottenBanana\rottenBanana (1).webp
# Image not in correct form: train\RottenBanana\rottenBanana (271).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (1).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (137).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (138).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (141).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (142).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (143).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (144).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (145).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (146).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (147).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (148).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (150).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (151).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (152).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (279).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (281).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (282).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (283).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (284).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (285).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (286).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (287).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (288).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (290).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (291).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (292).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (293).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (296).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (297).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (298).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (300).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (301).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (422).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (423).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (430).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (431).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (433).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (434).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (435).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (437).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (438).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (439).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (449).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (450).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (451).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (452).jpg
# Image not in correct form: train\RottenBellpepper\rottenPepper (453).jpg
# Image not in correct form: train\RottenCarrot\rottenCarrot (1).webp
# Image not in correct form: train\RottenCarrot\rottenCarrot (342).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (262).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (263).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (267).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (274).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (388).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (389).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (390).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (391).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (393).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (394).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (395).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (396).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (397).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (398).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (399).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (400).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (401).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (403).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (404).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (405).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (406).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (407).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (408).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (409).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (411).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (413).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (414).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (415).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (416).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (417).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (419).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (420).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (421).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (423).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (425).jpg
# Image not in correct form: train\RottenCucumber\rottenCucumber (426).jpg
# Image not in correct form: train\RottenMango\rottenMango (322).jpg
# Image not in correct form: train\RottenMango\rottenMango (333).jpg
# Image not in correct form: train\RottenMango\rottenMango (334).jpg
# Image not in correct form: train\RottenMango\rottenMango (335).jpg
# Image not in correct form: train\RottenMango\rottenMango (356).jpg
# Image not in correct form: train\RottenOrange\rottenOrange (246).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (1).webp
# Image not in correct form: train\RottenPotato\rottenPotato (113).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (129).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (130).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (425).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (487).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (488).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (489).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (490).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (505).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (506).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (507).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (509).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (510).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (516).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (517).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (518).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (519).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (520).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (521).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (522).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (527).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (532).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (533).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (537).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (538).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (539).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (540).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (541).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (542).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (543).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (544).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (545).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (546).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (547).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (548).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (549).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (551).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (552).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (554).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (562).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (564).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (61).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (62).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (63).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (64).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (73).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (75).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (78).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (85).jpg
# Image not in correct form: train\RottenPotato\rottenPotato (86).jpg
# Image not in correct form: train\RottenStrawberry\rottenStrawberry (349).jpg
# Image not in correct form: train\RottenStrawberry\rottenStrawberry (351).jpg
# Image not in correct form: train\RottenStrawberry\rottenStrawberry (412).jpg
# Image not in correct form: train\RottenStrawberry\rottenStrawberry (426).jpg
# Image not in correct form: train\RottenTomato\rottenTomato (1).webp
# Image not in correct form: train\RottenTomato\rottenTomato (20).jpg
# Image not in correct form: train\RottenTomato\rottenTomato (21).jpg
# Image not in correct form: train\RottenTomato\rottenTomato (71).jpg
# Image not in correct form: train\RottenTomato\rottenTomato (72).jpg
# Image not in correct form: train\RottenTomato\rottenTomato (76).jpg

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
                   train_directory,
                    shuffle = True,
                    image_size= (img_width , img_height),
                    batch_size = 32,
                    validation_split = False)
# Out:
# Found 11522 files belonging to 20 classes.

# %%
data_cat=data_train.class_names

# %%
len(data_cat)
# Out:
# 20

# %%
import os
import cv2
import imghdr

image_exts = ['jpeg', 'png', 'jpg', 'gif', 'bmp']  # Supported image extensions

for image_class in os.listdir(test_directory):
    class_dir = os.path.join(test_directory, image_class)
    if os.path.isdir(class_dir):  # Ensure it's a directory
        for image in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image)
            try:
                img = cv2.imread(image_path)
                tip = imghdr.what(image_path)
                if tip not in image_exts:
                    print('Image not in correct form: {}'.format(image_path))
                    os.remove(image_path)
            except Exception as e:
                print('Issue with image {}: {}'.format(image_path, e))
# Out:
# Issue with image test\FreshApple\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\FreshApple\\.ipynb_checkpoints'
# Image not in correct form: test\FreshBanana\freshBanana (1).webp
# Issue with image test\FreshBellpepper\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\FreshBellpepper\\.ipynb_checkpoints'
# Image not in correct form: test\FreshCucumber\freshCucumber (104).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (110).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (118).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (125).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (126).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (141).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (144).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (149).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (150).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (45).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (49).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (53).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (541).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (550).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (567).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (570).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (573).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (575).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (576).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (581).jpg
# Image not in correct form: test\FreshCucumber\freshCucumber (90).jpg
# Issue with image test\FreshMango\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\FreshMango\\.ipynb_checkpoints'
# Issue with image test\FreshOrange\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\FreshOrange\\.ipynb_checkpoints'
# Image not in correct form: test\RottenApple\rottenApple (1).webp
# Image not in correct form: test\RottenApple\rottenApple (467).jpg
# Issue with image test\RottenBanana\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\RottenBanana\\.ipynb_checkpoints'
# Image not in correct form: test\RottenBanana\rottenBanana (3).webp
# Issue with image test\RottenBellpepper\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\RottenBellpepper\\.ipynb_checkpoints'
# Image not in correct form: test\RottenBellpepper\rottenPepper (139).jpg
# Image not in correct form: test\RottenBellpepper\rottenPepper (280).jpg
# Image not in correct form: test\RottenBellpepper\rottenPepper (299).jpg
# Image not in correct form: test\RottenBellpepper\rottenPepper (436).jpg
# Issue with image test\RottenCucumber\.ipynb_checkpoints: [Errno 13] Permission denied: 'test\\RottenCucumber\\.ipynb_checkpoints'
# Image not in correct form: test\RottenCucumber\rottenCucumber (392).jpg
# Image not in correct form: test\RottenCucumber\rottenCucumber (424).jpg
# Image not in correct form: test\RottenMango\rottenMango (323).jpg
# Image not in correct form: test\RottenPotato\rottenPotato (74).jpg

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
                   test_directory,
                    shuffle = False,
                    image_size= (img_width , img_height),
                    batch_size = 32,
                    validation_split = False)
# Out:
# Found 3230 files belonging to 20 classes.

# %%
data_test.class_names
# Out:
# ['FreshApple',
#  'FreshBanana',
#  'FreshBellpepper',
#  'FreshCarrot',
#  'FreshCucumber',
#  'FreshMango',
#  'FreshOrange',
#  'FreshPotato',
#  'FreshStrawberry',
#  'FreshTomato',
#  'RottenApple',
#  'RottenBanana',
#  'RottenBellpepper',
#  'RottenCarrot',
#  'RottenCucumber',
#  'RottenMango',
#  'RottenOrange',
#  'RottenPotato',
#  'RottenStrawberry',
#  'RottenTomato']

# %%
import os
import cv2
import imghdr

image_exts = ['jpeg', 'png', 'jpg', 'gif', 'bmp']  # Supported image extensions

for image_class in os.listdir(val_directory):
    class_dir = os.path.join(val_directory, image_class)
    if os.path.isdir(class_dir):  # Ensure it's a directory
        for image in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image)
            try:
                img = cv2.imread(image_path)
                tip = imghdr.what(image_path)
                if tip not in image_exts:
                    print('Image not in correct form: {}'.format(image_path))
                    os.remove(image_path)
            except Exception as e:
                print('Issue with image {}: {}'.format(image_path, e))
# Out:
# Image not in correct form: val\FreshCucumber\freshCucumber (101).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (107).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (116).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (121).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (132).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (154).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (207).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (533).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (539).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (543).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (544).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (545).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (546).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (556).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (56).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (61).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (65).jpg
# Image not in correct form: val\FreshCucumber\freshCucumber (81).jpg
# Image not in correct form: val\RottenApple\rottenApple (464).jpg
# Image not in correct form: val\RottenBanana\rottenBanana (2).webp
# Image not in correct form: val\RottenBanana\rottenBanana (240).jpg
# Image not in correct form: val\RottenBellpepper\rottenPepper (140).jpg
# Image not in correct form: val\RottenBellpepper\rottenPepper (149).jpg
# Image not in correct form: val\RottenBellpepper\rottenPepper (289).jpg
# Image not in correct form: val\RottenBellpepper\rottenPepper (294).jpg
# Image not in correct form: val\RottenBellpepper\rottenPepper (295).jpg
# Image not in correct form: val\RottenCucumber\rottenCucumber (402).jpg
# Image not in correct form: val\RottenCucumber\rottenCucumber (410).jpg
# Image not in correct form: val\RottenCucumber\rottenCucumber (412).jpg
# Image not in correct form: val\RottenCucumber\rottenCucumber (418).jpg
# Image not in correct form: val\RottenCucumber\rottenCucumber (422).jpg
# Image not in correct form: val\RottenPotato\rottenPotato (136).jpg
# Image not in correct form: val\RottenPotato\rottenPotato (486).jpg
# Image not in correct form: val\RottenPotato\rottenPotato (534).jpg
# Image not in correct form: val\RottenStrawberry\rottenStrawberry (25).jpeg
# Image not in correct form: val\RottenStrawberry\rottenStrawberry (365).jpg
# Image not in correct form: val\RottenStrawberry\rottenStrawberry (423).jpg

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
                   val_directory,
                    shuffle = False,
                    image_size= (img_width , img_height),
                    batch_size = 32,
                    validation_split = False)
# Out:
# Found 3217 files belonging to 20 classes.

# %%
data_train
data_val
data_test
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 361/361 [==============================] - 202s 554ms/step - loss: 1.8579 - accuracy: 0.4538 - val_loss: 1.0489 - val_accuracy: 0.6979
# Epoch 2/25
# 361/361 [==============================] - 192s 531ms/step - loss: 0.9861 - accuracy: 0.7093 - val_loss: 0.7150 - val_accuracy: 0.7889
# Epoch 3/25
# 361/361 [==============================] - 202s 559ms/step - loss: 0.6233 - accuracy: 0.8161 - val_loss: 0.3743 - val_accuracy: 0.8856
# Epoch 4/25
# 361/361 [==============================] - 187s 516ms/step - loss: 0.3995 - accuracy: 0.8790 - val_loss: 0.2637 - val_accuracy: 0.9210
# Epoch 5/25
# 361/361 [==============================] - 186s 513ms/step - loss: 0.2615 - accuracy: 0.9195 - val_loss: 0.2436 - val_accuracy: 0.9235
# Epoch 6/25
# 361/361 [==============================] - 187s 516ms/step - loss: 0.1742 - accuracy: 0.9425 - val_loss: 0.1552 - val_accuracy: 0.9534
# Epoch 7/25
# 361/361 [==============================] - 187s 516ms/step - loss: 0.1433 - accuracy: 0.9563 - val_loss: 0.1417 - val_accuracy: 0.9574
# Epoch 8/25
# 361/361 [==============================] - 187s 518ms/step - loss: 0.1746 - accuracy: 0.9511 - val_loss: 0.1341 - val_accuracy: 0.9583
# Epoch 9/25
# 361/361 [==============================] - 190s 524ms/step - loss: 0.1157 - accuracy: 0.9649 - val_loss: 0.1102 - val_accuracy: 0.9705
# Epoch 10/25
# 361/361 [==============================] - 184s 510ms/step - loss: 0.0775 - accuracy: 0.9770 - val_loss: 0.0986 - val_accuracy: 0.9736
# Epoch 11/25
# 361/361 [==============================] - 189s 522ms/step - loss: 0.0898 - accuracy: 0.9726 - val_loss: 0.1397 - val_accuracy: 0.9596
# Epoch 12/25
# 361/361 [==============================] - 192s 531ms/step - loss: 0.0834 - accuracy: 0.9762 - val_loss: 0.0585 - val_accuracy: 0.9863
# Epoch 13/25
# 361/361 [==============================] - 194s 537ms/step - loss: 0.0752 - accuracy: 0.9767 - val_loss: 0.0993 - val_accuracy: 0.9726
# Epoch 14/25
# 361/361 [==============================] - 185s 511ms/step - loss: 0.0957 - accuracy: 0.9712 - val_loss: 0.0921 - val_accuracy: 0.9748
# Epoch 15/25
# 361/361 [==============================] - 202s 560ms/step - loss: 0.0883 - accuracy: 0.9742 - val_loss: 0.1371 - val_accuracy: 0.9689
# Epoch 16/25
# 361/361 [==============================] - 196s 541ms/step - loss: 0.0862 - accuracy: 0.9736 - val_loss: 0.0554 - val_accuracy: 0.9876
# Epoch 17/25
# 361/361 [==============================] - 207s 572ms/step - loss: 0.0666 - accuracy: 0.9801 - val_loss: 0.0519 - val_accuracy: 0.9885
# Epoch 18/25
# 361/361 [==============================] - 181s 501ms/step - loss: 0.0665 - accuracy: 0.9809 - val_loss: 0.1403 - val_accuracy: 0.9649
# Epoch 19/25
# 361/361 [==============================] - 177s 489ms/step - loss: 0.0606 - accuracy: 0.9832 - val_loss: 0.1311 - val_accuracy: 0.9689
# Epoch 20/25
# 361/361 [==============================] - 183s 506ms/step - loss: 0.0745 - accuracy: 0.9780 - val_loss: 0.0956 - val_accuracy: 0.9798
# Epoch 21/25
# 361/361 [==============================] - 183s 507ms/step - loss: 0.0529 - accuracy: 0.9853 - val_loss: 0.0620 - val_accuracy: 0.9882
# Epoch 22/25
# 361/361 [==============================] - 181s 502ms/step - loss: 0.0565 - accuracy: 0.9849 - val_loss: 0.0814 - val_accuracy: 0.9826
# Epoch 23/25
# 361/361 [==============================] - 183s 506ms/step - loss: 0.0562 - accuracy: 0.9828 - val_loss: 0.0649 - val_accuracy: 0.9854
# Epoch 24/25
# 361/361 [==============================] - 188s 520ms/step - loss: 0.0581 - accuracy: 0.9827 - val_loss: 0.0403 - val_accuracy: 0.9929
# Epoch 25/25
# 361/361 [==============================] - 189s 522ms/step - loss: 0.0543 - accuracy: 0.9842 - val_loss: 0.0826 - val_accuracy: 0.9817

# %%
 epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'test/RottenMango/rottenMango (117).jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'test/RottenMango/rottenMango (117).jpg'
img = mpimg.imread(image_path)
plt.figure(figsize=(8, 8)) 
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 237ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is RottenMango with accuracy of 99.99

# %%
image = 'test/RottenBanana/rottenBanana (113).jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'test/RottenBanana/rottenBanana (113).jpg'
img = mpimg.imread(image_path)
plt.figure(figsize=(8, 8)) 
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is RottenBanana with accuracy of 100.00

# %%
image = 'test/RottenTomato/rottenTomato (11).jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'test/RottenTomato/rottenTomato (11).jpg'
img = mpimg.imread(image_path)
plt.figure(figsize=(8, 8)) 
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is RottenTomato with accuracy of 100.00

# %%
image = 'test/FreshApple/freshApple (147).jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'test/FreshApple/freshApple (147).jpg'
img = mpimg.imread(image_path)
plt.figure(figsize=(8, 8)) 
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is FreshApple with accuracy of 100.00

# %%
image = 'test/FreshPotato/freshPotato (112).jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'test/FreshPotato/freshPotato (112).jpg'
img = mpimg.imread(image_path)
plt.figure(figsize=(8, 8)) 
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
predict = model.predict(img_bat)
score = tf.nn.softmax(predict)
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Veg/Fruit in image is FreshPotato with accuracy of 100.00

# %%
image = 'test/FreshCucumber/freshCucumber (15).jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'test/FreshCucumber/freshCucumber (15).jpg'
img = mpimg.imread(image_path)
plt.figure(figsize=(8, 8)) 
plt.imshow(img)
plt.axis('off')  
plt.show()

# %%
predict = model.predict(img_bat)
score = tf.nn.softmax(predict)
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Veg/Fruit in image is FreshCucumber with accuracy of 100.00
